# %% [markdown]
# # TDNN with Delay Line Size of 5

# %%
import matplotlib.pyplot as plt

epochs = range(25)
loss = [0.7054, 0.6974, 0.6921, 0.6876, 0.6820, 0.6742, 0.6626, 0.5949, 0.4949, 0.4449, 0.4119,
        0.3852, 0.3682, 0.3563, 0.3463, 0.3375, 0.3293, 0.3216, 0.3143, 0.3073, 0.3007, 0.2943,
        0.2883, 0.2825, 0.2770]
acc = [0.5163, 0.5362, 0.5562, 0.5612, 0.5675, 0.5838, 0.5975, 0.6500, 0.6687, 0.7138, 0.8213,
       0.9000, 0.9312, 0.9388, 0.9463, 0.9525, 0.9550, 0.9600, 0.9588, 0.9600, 0.9638, 0.9650,
       0.9675, 0.9700, 0.9712]


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax = ax1.twinx()

value = ax1.plot(epochs, loss, color="b", marker="o", label="Loss")
ax1.set_xlabel(r"Epochs")
ax1.set_ylabel(r"Loss")

rate = ax.plot(epochs, acc, color="r", marker="*", label="Accuracy")
ax.set_ylabel(r"Accuracy", rotation=-90)


legend = value+rate
vals = [l.get_label() for l in legend]
ax1.legend(legend, vals, prop=dict(size=10))
ax1.set_title(r"TDNN: Training Accuracy and Loss")

for item in ([ax1.xaxis.label, ax1.yaxis.label, ax.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + ax.get_yticklabels()):
    item.set_fontsize(9)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(25)
loss = [0.6992, 0.6923, 0.6873, 0.6818, 0.6744, 0.6635, 0.6437, 0.5286, 0.4567, 0.4198,
        0.3915, 0.3696, 0.3556, 0.3443, 0.3347, 0.3261, 0.3181, 0.3105, 0.3033, 0.2966,
        0.2900, 0.2839, 0.2781, 0.2724, 0.2669]
acc = [0.5150, 0.5450, 0.5650, 0.5850, 0.6250, 0.6250, 0.6450, 0.7050, 0.7100, 0.8200,
       0.9050, 0.9450, 0.9550, 0.9550, 0.9550, 0.9550, 0.9600, 0.9500, 0.9500, 0.9500,
       0.9500, 0.9500, 0.9600, 0.9600, 0.9650]


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax = ax1.twinx()

value = ax1.plot(epochs, loss, color="b", marker="o", label="Loss")
ax1.set_xlabel(r"Epochs")
ax1.set_ylabel(r"Loss")

rate = ax.plot(epochs, acc, color="r", marker="*", label="Accuracy")
ax.set_ylabel(r"Accuracy", rotation=-90)


legend = value+rate
vals = [l.get_label() for l in legend]
ax1.legend(legend, vals, prop=dict(size=10))
ax1.set_title(r"TDNN: Validation Accuracy and Loss")

for item in ([ax1.xaxis.label, ax1.yaxis.label, ax.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + ax.get_yticklabels()):
    item.set_fontsize(9)

plt.tight_layout()
plt.show()

# %% [markdown]
# # TDNN with Delay Line Size of 20

# %%
import matplotlib.pyplot as plt

epochs = range(25)
loss = [0.8162, 0.7134, 0.6914, 0.6650, 0.6121, 0.5381, 0.4862, 0.4587, 0.4402, 0.4266, 0.4153,
        0.4057, 0.3972, 0.3896, 0.3826, 0.3759, 0.3695, 0.3633, 0.3576, 0.3517, 0.3461, 0.3407,
        0.3354, 0.3304, 0.3255]
acc = [0.5000, 0.5175, 0.5163, 0.5487, 0.6050, 0.6737, 0.7625, 0.8000, 0.8475, 0.8687, 0.8788,
       0.8938, 0.8975, 0.9013, 0.9038, 0.9050, 0.9100, 0.9137, 0.9175, 0.9162, 0.9162, 0.9187,
       0.9187, 0.9200, 0.9262]


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax = ax1.twinx()

value = ax1.plot(epochs, loss, color="b", marker="o", label="Loss")
ax1.set_xlabel(r"Epochs")
ax1.set_ylabel(r"Loss")

rate = ax.plot(epochs, acc, color="r", marker="*", label="Accuracy")
ax.set_ylabel(r"Accuracy", rotation=-90)


legend = value+rate
vals = [l.get_label() for l in legend]
ax1.legend(legend, vals, prop=dict(size=10))
ax1.set_title(r"TDNN: Training Accuracy and Loss")

for item in ([ax1.xaxis.label, ax1.yaxis.label, ax.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + ax.get_yticklabels()):
    item.set_fontsize(8)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(25)
loss = [0.7375, 0.6969, 0.6752, 0.6357, 0.5563, 0.4839, 0.4464, 0.4245, 0.4092, 0.3971, 0.3872,
        0.3784, 0.3707, 0.3637, 0.3572, 0.3509, 0.3450, 0.3395, 0.3342, 0.3291, 0.3242, 0.3195,
        0.3151, 0.3107, 0.3068]
acc = [0.5300, 0.5650, 0.5000, 0.6100, 0.6600, 0.7700, 0.8250, 0.8800, 0.8900, 0.9000, 0.9050,
       0.9250, 0.9250, 0.9300, 0.9300, 0.9300, 0.9300, 0.9300, 0.9300, 0.9250, 0.9250, 0.9250,
       0.9250, 0.9250, 0.9300]


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax = ax1.twinx()

value = ax1.plot(epochs, loss, color="b", marker="o", label="Loss")
ax1.set_xlabel(r"Epochs")
ax1.set_ylabel(r"Loss")

rate = ax.plot(epochs, acc, color="r", marker="*", label="Accuracy")
ax.set_ylabel(r"Accuracy", rotation=-90)


legend = value+rate
vals = [l.get_label() for l in legend]
ax1.legend(legend, vals, prop=dict(size=10))
ax1.set_title(r"TDNN: Validation Accuracy and Loss")

for item in ([ax1.xaxis.label, ax1.yaxis.label, ax.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + ax.get_yticklabels()):
    item.set_fontsize(8)

plt.tight_layout()
plt.show()

# %% [markdown]
# # RNN

# %%
import matplotlib.pyplot as plt

epochs = range(30)
loss = [0.6847, 0.6562, 0.5850, 0.4815, 0.4303, 0.4120, 0.2956, 0.2521, 0.2147, 0.1884,
        0.1702, 0.1584, 0.1548, 0.1511, 0.1415, 0.1326, 0.1274, 0.1259, 0.1214, 0.1205,
        0.0979, 0.0981, 0.0973, 0.0968, 0.0964, 0.0962, 0.0961, 0.0960, 0.0958, 0.0959]
acc = [0.6012, 0.7412, 0.8725, 0.9550, 0.9388, 0.9062, 0.9650, 0.9650, 0.9663, 0.9663,
       0.9663, 0.9633, 0.9650, 0.9650, 0.9675, 0.9700, 0.9712, 0.9712, 0.9725, 0.9725,
       0.9800, 0.9800, 0.9800, 0.9800, 0.9800, 0.9800, 0.9800, 0.9800, 0.9800, 0.9800]


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax = ax1.twinx()

value = ax1.plot(epochs, loss, color="b", marker="o", label="Loss")
ax1.set_xlabel(r"Epochs")
ax1.set_ylabel(r"Loss")

rate = ax.plot(epochs, acc, color="r", marker="*", label="Accuracy")
ax.set_ylabel(r"Accuracy", rotation=-90)


legend = value+rate
vals = [l.get_label() for l in legend]
ax1.legend(legend, vals, prop=dict(size=10))
ax1.set_title(r"RNN: Training Accuracy and Loss")

for item in ([ax1.xaxis.label, ax1.yaxis.label, ax.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + ax.get_yticklabels()):
    item.set_fontsize(8)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(30)
loss = [0.6725, 0.6241, 0.5278, 0.4324, 0.3604, 0.3092, 0.2579, 0.2153, 0.1823, 0.1714, 0.1575,
        0.1472, 0.1173, 0.1120, 0.1083, 0.1052, 0.1030, 0.1208, 0.1199, 0.1194, 0.0887, 0.0871,
        0.0861, 0.0851, 0.0841, 0.0842, 0.0834, 0.0834, 0.0831, 0.0832]
acc = [0.7200, 0.8000, 0.9550, 0.9650, 0.9700, 0.9700, 0.9750, 0.9750, 0.9750, 0.9700, 0.9700,
       0.9700, 0.9800, 0.9800, 0.9800, 0.9800, 0.9800, 0.9750, 0.9750, 0.9750, 0.9850, 0.9850,
       0.9850, 0.9850, 0.9850, 0.9850, 0.9850, 0.9850, 0.9850, 0.9850]


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax = ax1.twinx()

value = ax1.plot(epochs, loss, color="b", marker="o", label="Loss")
ax1.set_xlabel(r"Epochs")
ax1.set_ylabel(r"Loss")

rate = ax.plot(epochs, acc, color="r", marker="*", label="Accuracy")
ax.set_ylabel(r"Accuracy", rotation=-90)


legend = value+rate
vals = [l.get_label() for l in legend]
ax1.legend(legend, vals, prop=dict(size=10))
ax1.set_title(r"RNN: Validation Accuracy and Loss")

for item in ([ax1.xaxis.label, ax1.yaxis.label, ax.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + ax.get_yticklabels()):
    item.set_fontsize(8)

plt.tight_layout()
plt.show()
